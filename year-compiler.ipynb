# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data/scimagojr country rank 2020.xlsx")
df_all = df.copy()
df_all['Year'] = '2020'

# %%
df = pd.read_excel("data/scimagojr country rank 2021.xlsx")
df['Year'] = '2021'
df_all = pd.concat([df_all, df], ignore_index=True)

# %%
df = pd.read_excel("data/scimagojr country rank 2022.xlsx")
df['Year'] = '2022'
df_all = pd.concat([df_all, df], ignore_index=True)

# %%
df = pd.read_excel("data/scimagojr country rank 2023.xlsx")
df['Year'] = '2023'
df_all = pd.concat([df_all, df], ignore_index=True)

# %%
df = pd.read_excel("data/scimagojr country rank 2024.xlsx")
df['Year'] = '2024'
df_all = pd.concat([df_all, df], ignore_index=True)

# %%
df_all.to_csv('data/scimagojr_country_rank.csv')
